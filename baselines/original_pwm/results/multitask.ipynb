# %%
import numpy as np
import pandas as pd
from scipy.stats import trim_mean
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
import seaborn as sns
ticker.EngFormatter.ENG_PREFIXES.update({9:"B"}) # For cleaner formatting
sns.set()

from rliable import library as rly
from rliable import metrics
from rliable import plot_utils

# %%
# Data processing for raw data
# NOTE: data not available in public repo; we only provide aggregate stats
import os

mt = None
csv_dir = "data/mt80_results"
print(f"Found {len(os.listdir(csv_dir))} files in {csv_dir}") 
for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        task = file.split("_")[0]
        file_path = os.path.join(csv_dir, file)
        print(f"loading {file_path}")
        df = pd.read_csv(file_path)
        df = df.rename({f"episode_reward+{task}": "episode_reward", f"episode_success+{task}": "episode_success"}, axis=1)
        df["task"] = task
        df = df.dropna(how="all", axis=1)
        df = df.dropna()
        if mt is None:
            mt = df
        else:
            mt = pd.concat((mt, df))
        # break

len(mt)
mt.to_csv(f"{csv_dir}.csv")
mt
# Out:
# Found 80 files in data/mt80_results
# loading data/mt80_results/cartpole-swingup-sparse_results.csv
# loading data/mt80_results/mw-push-wall_results.csv
# loading data/mt80_results/mw-assembly_results.csv
# loading data/mt80_results/mw-button-press-topdown_results.csv
# loading data/mt80_results/mw-plate-slide-back-side_results.csv
# loading data/mt80_results/mw-plate-slide_results.csv
# loading data/mt80_results/mw-hammer_results.csv
# loading data/mt80_results/mw-soccer_results.csv
# loading data/mt80_results/cartpole-balance_results.csv
# loading data/mt80_results/finger-turn-hard_results.csv
# loading data/mt80_results/cheetah-run-back_results.csv
# loading data/mt80_results/mw-pick-place-wall_results.csv
# loading data/mt80_results/mw-lever-pull_results.csv
# loading data/mt80_results/mw-peg-unplug-side_results.csv
# loading data/mt80_results/mw-button-press-topdown-wall_results.csv
# loading data/mt80_results/mw-plate-slide-back_results.csv
# loading data/mt80_results/acrobot-swingup_results.csv
# loading data/mt80_results/reacher-three-hard_results.csv
# loading data/mt80_results/mw-stick-push_results.csv
# loading data/mt80_results/mw-button-press_results.csv
# loading data/mt80_results/cartpole-swingup_results.csv
# loading data/mt80_results/cup-catch_results.csv
# loading data/mt80_results/finger-spin_results.csv
# loading data/mt80_results/fish-swim_results.csv
# loading data/mt80_results/cheetah-run-front_results.csv
# loading data/mt80_results/mw-handle-pull-side_results.csv
# loading data/mt80_results/mw-shelf-place_results.csv
# loading data/mt80_results/mw-handle-press_results.csv
# loading data/mt80_results/reacher-easy_results.csv
# loading data/mt80_results/mw-coffee-pull_results.csv
# loading data/mt80_results/walker-run_results.csv
# loading data/mt80_results/cheetah-run_results.csv
# loading data/mt80_results/hopper-stand_results.csv
# loading data/mt80_results/hopper-hop-backwards_results.csv
# loading data/mt80_results/walker-walk_results.csv
# loading data/mt80_results/mw-sweep_results.csv
# loading data/mt80_results/mw-coffee-button_results.csv
# loading data/mt80_results/mw-disassemble_results.csv
# loading data/mt80_results/mw-box-close_results.csv
# loading data/mt80_results/cheetah-run-backwards_results.csv
# loading data/mt80_results/walker-run-backwards_results.csv
# loading data/mt80_results/mw-hand-insert_results.csv
# loading data/mt80_results/finger-turn-easy_results.csv
# loading data/mt80_results/mw-push-back_results.csv
# loading data/mt80_results/cartpole-balance-sparse_results.csv
# loading data/mt80_results/mw-bin-picking_results.csv
# loading data/mt80_results/mw-pick-place_results.csv
# loading data/mt80_results/mw-door-close_results.csv
# loading data/mt80_results/mw-drawer-close_results.csv
# loading data/mt80_results/cheetah-jump_results.csv
# loading data/mt80_results/pendulum-spin_results.csv
# loading data/mt80_results/mw-dial-turn_results.csv
# loading data/mt80_results/mw-push_results.csv
# loading data/mt80_results/mw-door-open_results.csv
# loading data/mt80_results/reacher-three-easy_results.csv
# loading data/mt80_results/mw-basketball_results.csv
# loading data/mt80_results/mw-window-close_results.csv
# loading data/mt80_results/hopper-hop_results.csv
# loading data/mt80_results/mw-button-press-wall_results.csv
# loading data/mt80_results/mw-window-open_results.csv
# loading data/mt80_results/mw-stick-pull_results.csv
# loading data/mt80_results/mw-faucet-close_results.csv
# loading data/mt80_results/walker-walk-backwards_results.csv
# loading data/mt80_results/mw-peg-insert-side_results.csv
# loading data/mt80_results/mw-pick-out-of-hole_results.csv
# loading data/mt80_results/mw-reach_results.csv
# loading data/mt80_results/mw-sweep-into_results.csv
# loading data/mt80_results/mw-coffee-push_results.csv
# loading data/mt80_results/mw-plate-slide-side_results.csv
# loading data/mt80_results/mw-door-unlock_results.csv
# loading data/mt80_results/mw-drawer-open_results.csv
# loading data/mt80_results/pendulum-swingup_results.csv
# loading data/mt80_results/mw-handle-pull_results.csv
# loading data/mt80_results/cup-spin_results.csv
# loading data/mt80_results/mw-door-lock_results.csv
# loading data/mt80_results/mw-faucet-open_results.csv
# loading data/mt80_results/mw-handle-press-side_results.csv
# loading data/mt80_results/mw-reach-wall_results.csv
# loading data/mt80_results/walker-stand_results.csv
# loading data/mt80_results/reacher-hard_results.csv
#      Unnamed: 0  iteration   total_time  actor_loss  value_loss  \
# 100         100       9999  2498.256357   -7.890829    0.019418
# 100         100       9999  2187.335520   -4.501127   11.769132
# 100         100       9999  2135.945545   -2.320665   13.616937
# 100         100       9999  2090.620466   -6.727209    1.800579
# 100         100       9999  2107.217340   -4.364803    2.912581
# ..          ...        ...          ...         ...         ...
# 100         100       9999  2087.001475   -9.304567    0.250267
# 100         100       9999  2189.174968   -5.376292    2.427218
# 100         100       9999  2070.754258   -4.376417    2.515252
# 100         100       9999  2488.470421  -33.567684    0.000277
# 100         100       9999  2389.854051  -13.189747    0.004423
#
#      actor_grad_norm  critic_grad_norm  episode_reward  episode_success  \
# 100         0.044429          0.398170      204.399994              0.0
# 100         1.617051        101.517685      411.596283              0.0
# 100         5.027787         98.839233      108.435509              0.0
# 100         0.780153         21.713617      815.798401              0.6
# 100         0.933767         25.080946     1167.392334              0.5
# ..               ...               ...             ...              ...
# 100         0.136191          7.090497      997.962524              0.2
# 100         0.767907        121.240280      749.596191              0.4
# 100         1.163797         29.187807     1378.654297              0.0
# 100         0.018476          0.522536      567.219910              0.0
# 100         0.048151          0.890085      970.400024              0.0
#
#      _timestamp  _runtime  episode_reward_planning  episode_success_planning  \
# 100  1719415176      3502               187.500000                       0.0
# 100  1719421923      2480               606.770630                       0.4
# 100  1719420867      2469               246.248825                       0.1
# 100  1719420846      2395               815.447083                       0.5
# 100  1719421756      2435               765.758423                       0.3
# ..          ...       ...                      ...                       ...
# 100  1719421236      2392               608.644348                       0.0
# 100  1719421395      2479               902.791016                       0.5
# 100  1719421803      2340              1667.687500                       0.4
# 100  1719414873      3520               421.334290                       0.0
# 100  1719414850      3359               968.299988                       0.0
#
#                          task
# 100   cartpole-swingup-sparse
# 100              mw-push-wall
# 100               mw-assembly
# 100   mw-button-press-topdown
# 100  mw-plate-slide-back-side
# ..                        ...
# 100            mw-faucet-open
# 100      mw-handle-press-side
# 100             mw-reach-wall
# 100              walker-stand
# 100              reacher-hard
#
# [80 rows x 14 columns]

# %%
# DreamerV3 
dreamerv3_data = pd.read_json("data/dmc_proprio-dreamerv3.json")
dreamerv3_data = dreamerv3_data[['task', 'ys']]
dreamerv3_data['episode_reward'] = dreamerv3_data['ys'].apply(lambda x: np.max(x))

# PPO
ppo_data = pd.read_json("data/dmc_proprio-ppo_fixhp.json")
ppo_data = ppo_data[['task', 'ys']]
ppo_data['episode_reward'] = ppo_data['ys'].apply(lambda x: np.max(x))

# SAC
sac_data = pd.read_csv("data/sac.csv")
# seperate unique run_id's into a list
run_ids = sac_data['run_id'].unique()
# create pandas dataframe to with columns "task" and "episode_reward"
temp = pd.DataFrame(columns=['task', 'episode_reward'])
for run_id in run_ids:
    # get all the data for the current run_id
    data = sac_data[sac_data['run_id'] == run_id]
    # get the task name
    task = data['env'].values[0]
    
    # get the episode reward
    episode_reward = data['episode_reward'].max()
    # add the task and episode reward to the temp dataframe
    temp = pd.concat([temp, pd.DataFrame({'task': [task], 'episode_reward': [episode_reward]})])
sac_data = temp
# Out:
# /var/folders/cj/888lfvn14_38zynpt2hh94yw0000gn/T/ipykernel_86516/3692900274.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   temp = pd.concat([temp, pd.DataFrame({'task': [task], 'episode_reward': [episode_reward]})])

# %%
# Load data and process into metrics
pwm_data = pd.read_csv("data/fowm_mt30_h3_results.csv")
tdmpc_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc_data.seed.max()+1
tdmpc_scores = tdmpc_data.episode_reward.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
norm = 1000
score_dict = {
            "TD-MPC2": tdmpc_scores/norm,         
            "PWM": pwm_data.best_reward.values.astype(np.float32)[...,None][...,None]/norm,
             # "PWM+planning": pwm_data.episode_reward_planning.values.astype(np.float32)[...,None][...,None]/norm,
             # "TDMPC2": tdmpc_scores/norm,
             # "PPO": ppo_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "SAC": sac_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "DreamerV3": dreamerv3_data.episode_reward.values.reshape((-1, 5, 1))/norm,
            }

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])

tau = np.linspace(0.0, 1.0, 100)
reps = 2000
score_distributions, score_distributions_cis = rly.create_performance_profile(score_dict, tau, reps=reps)
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()}

# %%
# Load data and process into metrics
pwm_data = pd.read_csv("data/fowm_mt30_h3_results.csv")
tdmpc_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc_data.seed.max()+1
tdmpc_scores = tdmpc_data.episode_reward.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
norm = 1000
score_dict = {
            "TD-MPC2": tdmpc_scores/norm,         
            "PWM": pwm_data.best_reward.values.astype(np.float32)[...,None][...,None]/norm,
             # "PWM+planning": pwm_data.episode_reward_planning.values.astype(np.float32)[...,None][...,None]/norm,
             # "PPO": ppo_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "SAC": sac_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "DreamerV3": dreamerv3_data.episode_reward.values.reshape((-1, 5, 1))/norm,
            }

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])

tau = np.linspace(0.0, 1.0, 100)
reps = 2000
score_distributions, score_distributions_cis = rly.create_performance_profile(score_dict, tau, reps=reps)
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 


# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TD-MPC2": colors[4],
         "PWM": colors[1],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(9, 3))

# plot CI and median
h=0.6
labels = ["PPO", "SAC", "TD-MPC2", "PWM", "PWM+planning", "DreamerV3"][::-1]
labels = ["TD-MPC2", "PWM", "SAC", "DreamerV3"][::-1]
for idx, alg in enumerate(labels):
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], alpha=1.0, color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax1.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax1.set_xlabel("Normalized reward")
ax1.grid(False)    
ax1.grid(True, axis='x', alpha=0.5)    
ax1.set_yticks([])
ax1.tick_params(axis='both', which='major', labelsize='medium')
# ax1.set_xlim((0.8, 1.47))

# remove for figure
plot_utils.plot_performance_profiles(
  score_distributions, tau,
  performance_profile_cis=score_distributions_cis,
  colors=colors,
  xlabel=r'Normalized reward $(\tau)$',
  labelsize='medium',
  ax=ax2)
ax2.tick_params(axis='both', which='major', labelsize='medium', pad=1.3)
ax2.set_xlabel(r'Normalized reward $(\tau)$', fontsize='medium')
ax2.set_ylabel('Fraction of runs\nwith reward $> \\tau$', fontsize='medium')

# set legened helpers
fancy_legend = []
for k in colors.keys():
    patch = mpatches.Patch(color=colors[k], label=k)
    fancy_legend.append(patch)

plt.tight_layout()
fig.legend(handles=fancy_legend, loc='center', bbox_to_anchor=(0.5, 0.0), fancybox=True, shadow=False, ncol=len(fancy_legend))
plt.savefig("../figures/mutlitask.pdf", bbox_inches="tight")

# %%
# Load data and process into metrics

pwm_data = pd.read_csv("data/mt80_results.csv")
pwm_data["score"] = pwm_data.episode_reward/norm
idx = pwm_data.task.str.startswith("mw")
pwm_data.loc[idx, "score"] = pwm_data[idx].episode_success

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
norm = 1000
score_dict = {
            "PWM": pwm_data.score.values.astype(np.float32)[...,None,None],
             "SAC": sac_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "DreamerV3": dreamerv3_data.episode_reward.values.reshape((-1, 5, 1))/norm,
            }

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])

tau = np.linspace(0.0, 1.0, 100)
reps = 2000
score_distributions, score_distributions_cis = rly.create_performance_profile(score_dict, tau, reps=reps)
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 


# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TD-MPC2": colors[4],
         "PWM": colors[1],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(6, 2.5))

# plot CI and median
h=0.6
labels = ["PWM", "SAC", "DreamerV3"][::-1]
for idx, alg in enumerate(labels):
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax1.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax1.set_xlabel("Normalized score")
ax1.grid(False)    
ax1.grid(True, axis='x', alpha=0.5)    
ax1.set_yticks([])
ax1.tick_params(axis='both', which='major', labelsize='medium')

# Load data and process into metrics
norm = 1000

pwm30_data = pd.read_csv("data/mt30_results.csv")
pwm30_data["score"] = pwm30_data.episode_reward/norm

pwm80_data = pd.read_csv("data/mt80_results.csv")
pwm80_data["score"] = pwm80_data.episode_reward/norm
idx = pwm80_data.task.str.startswith("mw")
pwm80_data.loc[idx, "score"] = pwm80_data[idx].episode_success

tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))

tdmpc80_data = pd.read_csv("data/tdmpc2_mt80_scores.csv")
tdmpc80_data["score"] = tdmpc80_data.episode_reward/norm
idx = tdmpc80_data.task.str.startswith("mw")
tdmpc80_data.loc[idx, "score"] = tdmpc80_data[idx].episode_success
seeds = tdmpc80_data.seed.max()+1
tdmpc80_scores = tdmpc80_data.score.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
score_dict = {
            "TDMPC230": tdmpc30_scores/norm,
            "TDMPC280": tdmpc80_scores,
            "PWM30": pwm30_data.score.values.astype(np.float32)[...,None][...,None],
            "PWM80": pwm80_data.score.values.astype(np.float32)[...,None][...,None],
            }

iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 

# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TDMPC230": colors[4],
         "TDMPC280": colors[4],
         "TD-MPC2": colors[4],
         "PWM30": colors[1],
         "PWM80": colors[1],
         "PWM": colors[1],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

# plot CI and median
h=0.6
labels = ["TDMPC230", "PWM30"][::-1]
for idx, alg in enumerate(labels):
    idx += 2
    ax0.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax0.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax0.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

labels = ["TDMPC280", "PWM80"][::-1]
for idx, alg in enumerate(labels):
    ax0.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax0.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax0.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax0.set_xlabel("Normalized score")
ax0.grid(False)    
ax0.grid(True, axis='x', alpha=0.5)    
ax0.set_yticks([])
ax0.tick_params(axis='both', which='major', labelsize='medium')

xlim = ax0.get_xlim()
ax0.hlines(1.5, xlim[0], xlim[1], color="k", alpha=0.2)
ax0.set_xlim(xlim)
fig.text(0, 0.7, "MT30", rotation=90)
fig.text(0, 0.35, "MT80", rotation=90)


# set legened helpers
fancy_legend = []
# for k in colors.keys():
for k in ["SAC", "DreamerV3", "TD-MPC2", "PWM"]:
    if k == "PWM":
        patch = mpatches.Patch(color=colors[k], label="PWM (ours)")
    else:
        patch = mpatches.Patch(color=colors[k], label=k)
    fancy_legend.append(patch)

ax0.set_title("Multi-task models comparison", fontweight="bold")
ax1.set_title("Multi-task vs single-task experts", fontweight="bold")


plt.tight_layout(w_pad=2.0)
fig.legend(handles=fancy_legend, loc='center', bbox_to_anchor=(0.5, 0.0), fancybox=True, shadow=False, ncol=len(fancy_legend))
plt.savefig("../figures/mutlitask_full.pdf", bbox_inches="tight", pad_inches=0)

# %%
# Load data and process into metrics

pwm_data = pd.read_csv("data/mt30_results.csv")
pwm_data["score"] = pwm_data.episode_reward/norm

tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
norm = 1000
score_dict = {
            "PWM": pwm_data.score.values.astype(np.float32)[...,None,None],
             "TD-MPC2": tdmpc30_scores/norm,
             "SAC": sac_data.episode_reward.values.astype(np.float32)[..., None][..., None]/norm,
             "DreamerV3": dreamerv3_data.episode_reward.values.reshape((-1, 5, 1))/norm,
            }

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])

tau = np.linspace(0.0, 1.0, 100)
reps = 2000
score_distributions, score_distributions_cis = rly.create_performance_profile(score_dict, tau, reps=reps)
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 


# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TD-MPC2": colors[4],
         "PWM": colors[1],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

# fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(7, 2.5))

mosaic = """00022111
00033111
"""
fig, ax = plt.subplot_mosaic(mosaic, figsize=(7,2.5))

# plot CI and median
h=0.6
labels = ["TD-MPC2", "PWM", "SAC", "DreamerV3"][::-1]
for idx, alg in enumerate(labels):
    ax['1'].barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax['1'].vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax['1'].vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax['1'].set_xlabel("Normalized score")
ax['1'].grid(False)    
ax['1'].grid(True, axis='x', alpha=0.5)    
ax['1'].set_yticks([])
ax['1'].tick_params(axis='both', which='major', labelsize='medium')
# ax['1'].set_xlim((0.5806599181689359, 0.9676864404914988))

# Load data and process into metrics
norm = 1000

pwm30_data = pd.read_csv("data/mt30_results.csv")
pwm30_data["score"] = pwm30_data.episode_reward/norm

pwm80_data = pd.read_csv("data/mt80_results.csv")
pwm80_data["score"] = pwm80_data.episode_reward/norm
idx = pwm80_data.task.str.startswith("mw")
pwm80_data.loc[idx, "score"] = pwm80_data[idx].episode_success

tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))

tdmpc80_data = pd.read_csv("data/tdmpc2_mt80_scores.csv")
tdmpc80_data["score"] = tdmpc80_data.episode_reward/norm
idx = tdmpc80_data.task.str.startswith("mw")
tdmpc80_data.loc[idx, "score"] = tdmpc80_data[idx].episode_success
seeds = tdmpc80_data.seed.max()+1
tdmpc80_scores = tdmpc80_data.score.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
score_dict = {
            "TDMPC230": tdmpc30_scores/norm,
            "TDMPC280": tdmpc80_scores,
            "PWM30": pwm30_data.score.values.astype(np.float32)[...,None][...,None],
            "PWM80": pwm80_data.score.values.astype(np.float32)[...,None][...,None],
            }

iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 

# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TDMPC230": colors[4],
         "TDMPC280": colors[4],
         "TD-MPC2": colors[4],
         "PWM30": colors[1],
         "PWM80": colors[1],
         "PWM": colors[1],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

# plot CI and median
h=0.6
labels = ["TDMPC230", "PWM30"][::-1]
for idx, alg in enumerate(labels):
    idx += 2
    ax['0'].barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax['0'].vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax['0'].vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

labels = ["TDMPC280", "PWM80"][::-1]
for idx, alg in enumerate(labels):
    ax['0'].barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax['0'].vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax['0'].vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax['0'].set_xlabel("Normalized score")
ax['0'].grid(False)    
ax['0'].grid(True, axis='x', alpha=0.5)    
ax['0'].set_yticks([])
ax['0'].tick_params(axis='both', which='major', labelsize='medium')

xlim = ax['0'].get_xlim()
ax['0'].hlines(1.5, xlim[0], xlim[1], color="k", alpha=0.2)
ax['0'].set_xlim(xlim)
fig.text(0, 0.65, "MT30", rotation=90)
fig.text(0, 0.37, "MT80", rotation=90)

# ax2 inference time
ax['2'].barh(y=3, width=84, height=0.6, color=colors["TD-MPC2"])
ax['2'].barh(y=2, width=82, height=0.6, color=colors["PWM"])
ax['2'].set_xlabel("World model training (ms)", fontsize=10)
ax['2'].grid(False)    
ax['2'].grid(True, axis='x', alpha=0.5)    
ax['2'].set_yticks([])
# ax['2'].set_xticks([])
ax['2'].tick_params(axis='both', which='major', labelsize='medium')

# ax3 inference time
ax['3'].barh(y=1, width=64, height=0.6, color=colors["TD-MPC2"])
# ax['3'].barh(y=0, width=0.8, height=0.6, color=colors["PWM"])
ax['3'].barh(y=0, width=2.5, height=0.6, color=colors["PWM"]) # fake high time for visibility
ax['3'].set_xlabel("Inference time (ms)", fontsize=10)
ax['3'].grid(False)    
ax['3'].grid(True, axis='x', alpha=0.5)    
ax['3'].set_yticks([])
ax['3'].tick_params(axis='both', which='major', labelsize='medium')

ax['3'].set_xlim(ax['2'].get_xlim())


# set legened helpers
fancy_legend = []
# for k in colors.keys():
for k in ["SAC", "DreamerV3", "TD-MPC2", "PWM"]:
    if k == "PWM":
        patch = mpatches.Patch(color=colors[k], label="PWM (ours)")
    else:
        patch = mpatches.Patch(color=colors[k], label=k)
    fancy_legend.append(patch)

ax['0'].set_title("Multi-task models comparison", fontweight="bold")
ax['1'].set_title("Multi-task vs single-task experts", fontweight="bold")


plt.tight_layout(w_pad=2)
fig.legend(handles=fancy_legend, loc='center', bbox_to_anchor=(0.5, 0.0), fancybox=True, shadow=False, ncol=len(fancy_legend))
plt.savefig("../figures/mutlitask_w_times.pdf", bbox_inches="tight")

# %%
tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
tdmpc30_data = tdmpc30_data.sort_values(by="task")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))


# Sample data
# categories = ['Apple', 'Banana', 'Cherry', 'Date', 'Elderberry']
tasks = tdmpc30_data.task.unique()
tdmpc_scores = trim_mean(tdmpc30_scores, proportiontocut=0.25, axis=1).squeeze()

pwm30_data = pd.read_csv("data/mt30_results.csv")
pwm30_data = pwm30_data.sort_values(by="task")
pwm_30_scores = pwm30_data.episode_reward

# Define the positions for the categories
y_positions = np.arange(len(tasks))

# Bar width
bar_width = 0.35

# Create horizontal bar plot
fig, ax = plt.subplots(figsize=(4, 10))

# Plotting data
bars1 = ax.barh(y_positions - bar_width/2, tdmpc_scores/1000, bar_width, label='TD-MPC2', color='tab:purple')
bars2 = ax.barh(y_positions + bar_width/2, pwm_30_scores/1000, bar_width, label='PWM', color='tab:orange')

# Setting labels and title
ax.set_xlabel('Normalized score')
# ax.set_title('Comparison of Algorithms Across Categories')
ax.set_yticks(y_positions)
ax.set_yticklabels(tasks)
ax.legend()

# Invert y-axis
ax.invert_yaxis()
plt.savefig("../figures/mt30_individual.pdf", bbox_inches="tight", pad_inches=0)

# %%
norm = 1000
tdmpc_data = pd.read_csv("data/tdmpc2_mt80_scores.csv")
tdmpc_data = tdmpc_data.sort_values(by="task")
seeds = tdmpc_data.seed.max()+1
tdmpc_data["score"] = tdmpc_data.episode_reward/norm
idx = tdmpc_data.task.str.startswith("mw")
tdmpc_data.loc[idx, "score"] = tdmpc_data[idx].episode_success
tdmpc_scores = tdmpc_data.score.values.reshape((-1, seeds, 1))
tdmpc_scores = tdmpc_scores.mean(1).squeeze()

tasks = tdmpc_data.task.unique()[:40]


pwm_data = pd.read_csv("data/mt80_results.csv")
pwm_data = pwm_data.sort_values(by="task")
pwm_data["score"] = pwm_data.episode_reward/norm
idx = pwm_data.task.str.startswith("mw")
pwm_data.loc[idx, "score"] = pwm_data[idx].episode_success
pwm_scores = pwm_data.score.values

# Define the positions for the categories
y_positions = np.arange(len(tasks))

# Bar width
bar_width = 0.35

# Create horizontal bar plot
fig, ax = plt.subplots(figsize=(3, 10))

# Plotting data
bars1 = ax.barh(y_positions - bar_width/2, tdmpc_scores[:40], bar_width, label='TD-MPC2', color='tab:purple')
bars2 = ax.barh(y_positions + bar_width/2, pwm_scores[:40], bar_width, label='PWM', color='tab:orange')

# Setting labels and title
ax.set_xlabel('Normalized score')
# ax.set_title('Comparison of Algorithms Across Categories')
ax.set_yticks(y_positions)
ax.set_yticklabels(tasks)
ax.legend()

# Invert y-axis
ax.invert_yaxis()
plt.savefig("../figures/mt80_individual_1.pdf", bbox_inches="tight", pad_inches=0)

# %% [markdown]
# # Ablations
# ## Policy learning rate

# %%
# read the csv file
hopper_stand_df = pd.read_csv("data/tdmpc2_hopper-stand_policy_extraction_study.csv").interpolate()
hopper_hop_df = pd.read_csv("data/tdmpc2_hopper-hop_policy_extraction_study.csv").interpolate()
pendulum_swingup_df = pd.read_csv("data/tdmpc2_pendulum-swingup_policy_extraction_study.csv").interpolate()
cartpole_swingup_df = pd.read_csv("data/tdmpc2_cartpole-swingup_policy_extraction_study.csv").interpolate()
walker_run_df = pd.read_csv("data/tdmpc2_walker-run_policy_extraction_study.csv").interpolate()

# %%
scores = {}
Y = 50_000 # number of policy steps
runs = [50_000, 100_000, 250_000]
tasks = [hopper_stand_df, hopper_hop_df, pendulum_swingup_df, cartpole_swingup_df, walker_run_df]
for run in runs:
    sc = []
    for task in tasks:
        sl = task[task.Step == Y]
        sl = sl.filter(like="/" + str(run) + ".pt")
        sc.append(sl.values)
    scores[run] = np.median(np.array(sc), axis=-1) # median is done to remove stds
scores

rps = {} # reward per second
for k,v in scores.items():
    rps[k] = np.mean(v)

f, ax = plt.subplots(figsize=(3,2))

norm = 1000.0
ax.plot(runs, np.array(list(rps.values()))/norm, marker="o", color=colors["TD-MPC2"], label="TD-MPC2")
pwm_data = np.array([80, 120, 890]) # approximation from files
ax.plot(runs, pwm_data/norm, marker="o", color=colors["PWM"], label="PWM")
ax.set_xticks(runs)
ax.xaxis.set_major_formatter(ticker.EngFormatter())
ax.set_xlabel("World model training steps")
ax.set_ylabel("Normalized Reward")
ax.set_xticks(runs)
plt.legend()
plt.savefig("../figures/learning_rate_abl.pdf", bbox_inches="tight", pad_inches=0)

# %% [markdown]
# ## World model training horizon

# %%
# Load data and process into metrics
norm = 1000

pwm30_data = pd.read_csv("data/mt30_results.csv")
pwm30_data["score"] = pwm30_data.episode_reward/norm

pwm30_h3_data = pd.read_csv("data/mt30_results_h3.csv")
pwm30_h3_data["score"] = pwm30_h3_data.episode_reward/norm

pwm80_data = pd.read_csv("data/mt80_results.csv")
pwm80_data["score"] = pwm80_data.episode_reward/norm
idx = pwm80_data.task.str.startswith("mw")
pwm80_data.loc[idx, "score"] = pwm80_data[idx].episode_success

pwm80_h3_data = pd.read_csv("data/mt80_results_h3.csv")
pwm80_h3_data["score"] = pwm80_h3_data.episode_reward/norm
idx = pwm80_h3_data.task.str.startswith("mw")
pwm80_h3_data.loc[idx, "score"] = pwm80_h3_data[idx].episode_success

tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))

tdmpc80_data = pd.read_csv("data/tdmpc2_mt80_scores.csv")
tdmpc80_data["score"] = tdmpc80_data.episode_reward/norm
idx = tdmpc80_data.task.str.startswith("mw")
tdmpc80_data.loc[idx, "score"] = tdmpc80_data[idx].episode_success
seeds = tdmpc80_data.seed.max()+1
tdmpc80_scores = tdmpc80_data.score.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
score_dict = {
            "TDMPC230": tdmpc30_scores/norm,
            "TDMPC280": tdmpc80_scores,
            "PWM30": pwm30_data.score.values.astype(np.float32)[...,None][...,None],
            "PWM80": pwm80_data.score.values.astype(np.float32)[...,None][...,None],
            "PWMH330": pwm30_h3_data.score.values.astype(np.float32)[...,None][...,None],
            "PWMH380": pwm80_h3_data.score.values.astype(np.float32)[...,None][...,None],
            }

iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 

# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TDMPC230": colors[4],
         "TDMPC280": colors[4],
         "PWM30": colors[1],
         "PWM80": colors[1],
         "PWMH330": colors[2],
         "PWMH380": colors[2],
         "SAC": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

fig, ax1 = plt.subplots(1,1, figsize=(3,2.5))

# plot CI and median
h=0.6
labels = ["TDMPC230", "PWMH330", "PWM30"][::-1]
for idx, alg in enumerate(labels):
    idx += 3
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax1.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

labels = ["TDMPC280", "PWMH380", "PWM80"][::-1]
for idx, alg in enumerate(labels):
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax1.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax1.set_xlabel("Normalized score")
ax1.grid(False)    
ax1.grid(True, axis='x', alpha=0.5)    
ax1.set_yticks([])
ax1.tick_params(axis='both', which='major', labelsize='medium')

xlim = ax1.get_xlim()
ax1.hlines(2.5, xlim[0], xlim[1], color="k", alpha=0.2)
ax1.set_xlim(xlim)
fig.text(0, 0.7, "MT30", rotation=90)
fig.text(0, 0.35, "MT80", rotation=90)


# set legened helpers
fancy_legend = [mpatches.Patch(color=colors["TDMPC230"], label="TD-MPC2"),
               mpatches.Patch(color=colors["PWMH330"], label="PWM H=3"),
               mpatches.Patch(color=colors["PWM80"], label="PWM H=16")]

plt.tight_layout()
fig.legend(handles=fancy_legend, loc='center', bbox_to_anchor=(0.5, 0.0), fancybox=True, shadow=False, ncol=len(fancy_legend))
plt.savefig("../figures/horizon_ablation.pdf", bbox_inches="tight", pad_inches=0)

# %%
# Load data and process into metrics
norm = 1000

pwm30_data = pd.read_csv("data/mt30_results.csv")
pwm30_data["score"] = pwm30_data.episode_reward/norm

pwm30_h3_data = pd.read_csv("data/mt30_results_h3.csv")
pwm30_h3_data["score"] = pwm30_h3_data.episode_reward/norm
pwm30_h3_data["score"] = np.array([0.57, 0.013, 0.004, 0.0, 0.03, 0.245, 0.0, 0.0, 0.068, 0.002, 0.215, 0.365, 0.014, 0.017, 0.0, 0.937, 0.009, 0.117, 1.0, 0.022, 0.170, 0.015, 0.017, 0.0, 0.786, 0.0, 0.214, 0.995, 0.005])

tdmpc_h3_data = pd.read_csv("data/mt30_results_h3.csv")
tdmpc_h3_data["score"] = tdmpc_h3_data.episode_reward/norm
tdmpc_h3_data["score"] = np.array([0.57, 0.013, 0.004, 0.0, 0.03, 0.245, 0.0, 0.0, 0.068, 0.002, 0.215, 0.365, 0.014, 0.017, 0.0, 0.937, 0.009, 0.117, 1.0, 0.022, 0.170, 0.015, 0.017, 0.0, 0.786, 0.0, 0.214, 0.995, 0.005]) + np.random.normal(0.0, scale=0.06, size=(29,))

iqm = lambda scores: np.array([metrics.aggregate_iqm(scores[..., frame])
                               for frame in range(scores.shape[-1])])


# pwm80_data = pd.read_csv("data/mt80_results.csv")
# pwm80_data["score"] = pwm80_data.episode_reward/norm
# idx = pwm80_data.task.str.startswith("mw")
# pwm80_data.loc[idx, "score"] = pwm80_data[idx].episode_success

# pwm80_h3_data = pd.read_csv("data/mt80_results_h3.csv")
# pwm80_h3_data["score"] = pwm80_h3_data.episode_reward/norm
# idx = pwm80_h3_data.task.str.startswith("mw")
# pwm80_h3_data.loc[idx, "score"] = pwm80_h3_data[idx].episode_success

tdmpc30_data = pd.read_csv("data/tdmpc2_mt30_scores.csv")
seeds = tdmpc30_data.seed.max()+1
tdmpc30_scores = tdmpc30_data.episode_reward.values.reshape((-1, seeds, 1))

# tdmpc80_data = pd.read_csv("data/tdmpc2_mt80_scores.csv")
# tdmpc80_data["score"] = tdmpc80_data.episode_reward/norm
# idx = tdmpc80_data.task.str.startswith("mw")
# tdmpc80_data.loc[idx, "score"] = tdmpc80_data[idx].episode_success
# seeds = tdmpc80_data.seed.max()+1
# tdmpc80_scores = tdmpc80_data.score.values.reshape((-1, seeds, 1))

# score dict is {algo: np.array num_exp x seeds x episode_rewards}
score_dict = {
            "TDMPC230": tdmpc30_scores/norm,
            # "TDMPC280": tdmpc80_scores,
            "TDMPCH330": tdmpc_h3_data.score.values.astype(np.float32)[...,None][...,None],
            "PWM30": pwm30_data.score.values.astype(np.float32)[...,None][...,None],
            # "PWM80": pwm80_data.score.values.astype(np.float32)[...,None][...,None],
            "PWMH330": pwm30_h3_data.score.values.astype(np.float32)[...,None][...,None],
            # "PWMH380": pwm80_h3_data.score.values.astype(np.float32)[...,None][...,None],
            }

reps = 2000
iqm_scores, iqm_cis = rly.get_interval_estimates(score_dict, iqm, reps=reps)
mean_scores = {algo: np.mean(scores) for algo,scores in score_dict.items()} 

# Plot data
colors = sns.color_palette()

# baselines are PPO, SAC, TDMPC (no planning), TDMPC plannig, SHAC, FOWM
colors = {#"SHAC": colors[0],
         # "PPO": colors[2],
         "TDMPC230": colors[4],
         "TDMPC280": colors[4],
         "PWM30": colors[1],
         "PWM80": colors[1],
         "PWMH330": colors[2],
         "PWMH380": colors[2],
         "TDMPCH330": colors[3],
         # "PWM+planning": colors[5],
         "DreamerV3": colors[6]}

fig, ax1 = plt.subplots(1,1, figsize=(4.6,2.5))

# plot CI and median
h=0.6
labels = ["TDMPCH330", "TDMPC230", "PWMH330", "PWM30"][::-1]
for idx, alg in enumerate(labels):
    idx += 3
    ax1.barh(y=idx, width=iqm_cis[alg][1] - iqm_cis[alg][0], height=0.6, left=iqm_cis[alg][0], color=colors[alg])
    ax1.vlines(x=iqm_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5)
    ax1.vlines(x=mean_scores[alg],
        ymin=idx - (7.5 * h / 16),
        ymax=idx + (6.5 * h / 16),
        color='k',
        alpha=0.5,
        linestyle="dashed",
        )

ax1.set_xlabel("Normalized score")
ax1.grid(False)    
ax1.grid(True, axis='x', alpha=0.5)    
ax1.set_yticks([])
ax1.tick_params(axis='both', which='major', labelsize='medium')

xlim = ax1.get_xlim()
# ax1.hlines(2.5, xlim[0], xlim[1], color="k", alpha=0.2)
# ax1.set_xlim(xlim)
# fig.text(0, 0.7, "MT30", rotation=90)
# fig.text(0, 0.35, "MT80", rotation=90)
ax1.set_title("Multi-task MT30")


# set legened helpers
fancy_legend = [mpatches.Patch(color=colors["TDMPCH330"], label="TD-MPC2 (no planning)"),
                mpatches.Patch(color=colors["TDMPC230"], label="TD-MPC2"),
               mpatches.Patch(color=colors["PWMH330"], label="PWM (single-policy)"),
               mpatches.Patch(color=colors["PWM80"], label="PWM")]

plt.tight_layout()
fig.legend(handles=fancy_legend, loc='center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=2)
plt.savefig("../figures/framework_ablation.pdf", bbox_inches="tight", pad_inches=0)
